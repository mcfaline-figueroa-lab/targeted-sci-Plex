# %% [markdown]
# # MrVI Quick Start Tutorial
#
# MrVI (Multi-resolution Variational Inference) is a model for analyzing multi-sample single-cell RNA-seq data. This tutorial will guide you through the main features of MrVI.
# MrVI is particularly suited for single-cell RNA sequencing datasets with comparable observations across many samples. By comparable, we mean observations derived from the same tissue or from the same cell line. This ensures that MrVI can provide accurate, single-cell-resolution estimates.

# %%
# !pip install --quiet scvi-colab
from scvi_colab import install

install()
# Out:
# INFO     scvi-colab: Installing scvi-tools.
# INFO     scvi-colab: Install successful. Testing import.
# /usr/local/lib/python3.12/dist-packages/pyro/ops/stats.py:527: SyntaxWarning: invalid escape sequence '\g'
#   we have :math:`ES^{*}(P,Q) \ge ES^{*}(Q,Q)` with equality holding if and only if :math:`P=Q`, i.e.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import scipy.io
import scipy.sparse
import anndata as ad

# %%
# 1. Load the count matrix (sparse format)
X = scipy.io.mmread("/content/drive/My Drive/Decipher/matrix.mtx").tocsr()  # or .tocsc(), depending on access pattern

# 2. Load observation (cell) and variable (gene) metadata
obs = pd.read_csv("/content/drive/My Drive/Decipher/obs.csv", index_col=0)
var = pd.read_csv("/content/drive/My Drive/Decipher/var.csv", index_col=0)

# 3. Check that dimensions match
assert X.shape[0] == obs.shape[0], "Number of rows in matrix != number of cells in obs"
assert X.shape[1] == var.shape[0], "Number of cols in matrix != number of genes in var"

# 4. Create AnnData object
adata = ad.AnnData(X=X, obs=obs, var=var)

# %%
# !pip install scvi-tools@git+https://github.com/scverse/scvi-tools
# Out:
# Collecting scvi-tools@ git+https://github.com/scverse/scvi-tools
#   Cloning https://github.com/scverse/scvi-tools to /tmp/pip-install-qx1xqznm/scvi-tools_de80814ca1f542f0ba9ecb6cb3157db8
#   Running command git clone --filter=blob:none --quiet https://github.com/scverse/scvi-tools /tmp/pip-install-qx1xqznm/scvi-tools_de80814ca1f542f0ba9ecb6cb3157db8
#   Resolved https://github.com/scverse/scvi-tools to commit 3e275ffe00e85b73be5295864df0e1f99b94411f
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: anndata>=0.11 in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.12.6)
# Requirement already satisfied: docrep>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.3.2)
# Requirement already satisfied: lightning>=2.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.5.6)
# Requirement already satisfied: ml-collections in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.1.0)
# Requirement already satisfied: mudata in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.3.2)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.2.2)
# Requirement already satisfied: pyro-ppl in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.9.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (13.9.4)
# Requirement already satisfied: scanpy>=1.10 in /usr/local/lib/python3.12/dist-packages (from scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.11.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.16.3)
# Requirement already satisfied: sparse>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.17.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.19.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.9.0+cu126)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (4.67.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from scvi-tools@ git+https://github.com/scverse/scvi-tools) (2025.11.0)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.12.0)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.15.1)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (25.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.18.7)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from docrep>=0.3.2->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.17.0)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (6.0.3)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.15.2)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (4.15.0)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.5.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2025.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.5.2)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.10.0)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.5)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.5.13)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.13.2)
# Requirement already satisfied: session-info2 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.2.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.14.5)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.5.9.post2)
# Requirement already satisfied: scikit-misc>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.5.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml-collections->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.4.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from pyro-ppl->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->scvi-tools@ git+https://github.com/scverse/scvi-tools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.19.2)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools@ git+https://github.com/scverse/scvi-tools) (5.29.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.13.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy>=1.10->scanpy[skmisc]>=1.10->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.2.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.0.3)
# Requirement already satisfied: asciitree in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.3.3)
# Requirement already satisfied: fasteners in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.20)
# Requirement already satisfied: numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.15.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.22.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.12/dist-packages (from numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0->zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.3.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0->scvi-tools@ git+https://github.com/scverse/scvi-tools) (3.11)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0->zarr!=3.0.*,>=2.18.7->anndata>=0.11->scvi-tools@ git+https://github.com/scverse/scvi-tools) (1.17.3)

# %%
import scvi
from scvi.external import MRVI

# %% [markdown]
# install additionaly packges

# %%
# !pip install scanpy
# !pip install anndata
# Out:
# Collecting scanpy
#   Downloading scanpy-1.11.5-py3-none-any.whl.metadata (9.3 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.12.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.15.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.5.3)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy)
#   Downloading legacy_api_wrap-1.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba!=0.62.0rc1,>=0.57.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.6.1)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from scanpy) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.3-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy) (0.5.11)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.13.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.8->scanpy)
#   Downloading zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.62.0rc1,>=0.57.1->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->scanpy) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.3->scanpy) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->scanpy) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.3)
# Downloading scanpy-1.11.5-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.7 MB/s eta 0:00:00
# Downloading anndata-0.12.7-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 8.9 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.5-py3-none-any.whl (10 kB)
# Downloading session_info2-0.3-py3-none-any.whl (17 kB)
# Downloading array_api_compat-1.13.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 3.8 MB/s eta 0:00:00
# Downloading zarr-3.1.5-py3-none-any.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 6.5 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 35.2 MB/s eta 0:00:00
# Installing collected packages: session-info2, numcodecs, legacy-api-wrap, donfig, array-api-compat, zarr, anndata, scanpy
# Successfully installed anndata-0.12.7 array-api-compat-1.13.0 donfig-0.8.1.post1 legacy-api-wrap-1.5 numcodecs-0.16.5 scanpy-1.11.5 session-info2-0.3 zarr-3.1.5
# Requirement already satisfied: anndata in /usr/local/lib/python3.12/dist-packages (0.12.7)
# Requirement already satisfied: array-api-compat>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from anndata) (1.13.0)
# Requirement already satisfied: h5py>=3.8 in /usr/local/lib/python3.12/dist-packages (from anndata) (3.15.1)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.12/dist-packages (from anndata) (1.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from anndata) (8.4.0)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from anndata) (2.0.2)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.12/dist-packages (from anndata) (25.0)
# Requirement already satisfied: pandas!=2.1.2,<3,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from anndata) (2.2.2)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from anndata) (1.16.3)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /usr/local/lib/python3.12/dist-packages (from anndata) (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata) (2025.3)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.9 in /usr/local/lib/python3.12/dist-packages (from zarr!=3.0.*,>=2.18.7->anndata) (4.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.2,<3,>=2.1.0->anndata) (1.17.0)

# %%
# !pip install pymde
# Out:
# Collecting pymde
#   Downloading pymde-0.2.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pymde) (3.10.0)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from pymde) (2.0.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from pymde) (0.5.13)
# Requirement already satisfied: numba>=0.59.0 in /usr/local/lib/python3.12/dist-packages (from pymde) (0.60.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pymde) (1.15.3)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from pymde) (2.9.0+cpu)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.12/dist-packages (from pymde) (0.24.0+cpu)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pymde) (2.32.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.59.0->pymde) (0.43.0)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.12/dist-packages (from pynndescent>=0.5->pymde) (1.6.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pynndescent>=0.5->pymde) (1.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->pymde) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->pymde) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->pymde) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->pymde) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->pymde) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->pymde) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.1->pymde) (2025.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.8.2->pymde) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pymde) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pymde) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pymde) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pymde) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pymde) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pymde) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pymde) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pymde) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pymde) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pymde) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pymde) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pymde) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->pynndescent>=0.5->pymde) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7.1->pymde) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7.1->pymde) (3.0.3)
# Downloading pymde-0.2.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.4/186.4 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: pymde
# Successfully installed pymde-0.2.3

# %%
import pymde

# %%
import os
import tempfile

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import anndata as ad

scvi.settings.seed = 0  # optional: ensures reproducibility
print("Last run with scvi-tools version:", scvi.__version__)
save_dir = tempfile.TemporaryDirectory()

# %% [markdown]
# # Preprocessing and model fitting

# %%
adata
adata.obs['oligo'] = adata.obs['oligo'].str.replace(r'Media_\d+', 'Media', regex=True)
adata.obs['oligo'] = adata.obs['oligo'].str.replace(r'DMSO_\d+', 'DMSO', regex=True)

# %%
#new_adata = ad.AnnData(
    # X=transposed_data,
     #obs=adata.var.copy(),  # Copy var metadata to obs
     #var=adata.obs.copy()   # Copy obs metadata to var
#)
#del adata, transposed_data

# %%
adata
adata.var
sc.pp.filter_genes(adata, min_cells=int(0.005*adata.shape[0]))

# %%
# rename varnames to be id
#adata.var['gene_short_name'] = adata.var['gene_short_name'].astype(str)
adata.var_names = adata.var['id']
adata.var_names_make_unique()

# %%
len(list(set(adata.var_names)))
# Out:
# 7351

# %%
adata.layers["counts"] = adata.X.copy()
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata,
                            flavor='seurat',
                            n_top_genes=500,
                            inplace=True,
                            subset=False)

adata.X = adata.layers["counts"].copy()

# %%
adata = ad.read_h5ad(
    "/content/drive/My Drive/adata/jurkat/jurkat_2.h5ad"
)

# %%
#hvg_genes = adata.var_names[adata.var['highly_variable']].tolist()
probe_genes=["ENSG00000010610.9","ENSG00000081237.18","ENSG00000109471.4","ENSG00000110848.8","ENSG00000134460.15","ENSG00000153563.15","ENSG00000160654.9" ,"ENSG00000188389.10","ENSG00000277734.7" ]
all_target_genes = set(probe_genes)
adata = adata[:, adata.var_names.isin(all_target_genes)].copy()
adata
# Out:
# AnnData object with n_obs × n_vars = 50774 × 6
#     obs: 'cell', 'sample', 'n.umi', 'P7', 'P5', 'RT', 'Lig', 'oligo', 'hash_umis', 'total_hash_umis_per_cell', 'top_to_second_best_ratio', 'treatment', 'dose', 'log10.umi', 'percent_mito', 'num_genes_expressed', 'Size_Factor', 'Cluster'
#     var: 'id', 'gene_short_name', 'num_cells_expressed', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'log1p'

# %%
adata.write_h5ad(
    '/content/drive/My Drive/adata/jurkat/jurkat_probe_only.h5ad'
)

# %%
adata = ad.read_h5ad(
    "/content/drive/My Drive/adata/jurkat/jurkat_probe_only.h5ad"
)

# %% [markdown]
# Before training, we need to specify which covariates in `obs` should be used as target (`sample_key`) and nuisance variables (`batch_key`).
# In this tutorial, we will use donor IDs (`patient_id`) as the target variable, and leave the batch variable empty since the data is already subsetted to the Newcastle cohort (denoted in `Site`).
#
# Otherwise, we will focus on the following `obs` keys for the analysis:
# - `initial_clustering`: coarse cell-type annotations from the original study.
# - `Status`: whether the donor had COVID-19 or was healthy.
# - `Days_from_onset`: how many days it had been since the onset of symptoms before the sample was taken.

# %%
# batch_key="Site"  # nuisance variable identifier
MRVI.setup_anndata(adata, sample_key="oligo", batch_key="sample")
# Out:
# /tmp/ipython-input-237580595.py:2: UserWarning: MRVI model is being setup with JAX backend
#   MRVI.setup_anndata(adata, sample_key="oligo", batch_key="sample")
# /usr/local/lib/python3.12/dist-packages/scvi/data/fields/_base_field.py:63: UserWarning: adata.X does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)

# %%
model = MRVI(adata)
model.train(max_epochs=100)
# Out:
# INFO     Jax module moved to TFRT_CPU_0.Note: Pytorch lightning will show GPU is not being used for the Trainer.
# /tmp/ipython-input-519588078.py:2: UserWarning: Running mrVI with Jax version larger 0.4.35 can cause performance issues
#   model.train(max_epochs=100)
# /usr/local/lib/python3.12/dist-packages/scvi/dataloaders/_data_splitting.py:258: UserWarning: 1 cells moved from training set to validation set. if you want to avoid it please use train_size parameter during train.
#   self.n_train, self.n_val = validate_data_split(
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/trainer/connectors/data_connector.py:378: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.

# %% [markdown]
# Once trained, we can plot the ELBO of the model to check if the model has converged.

# %%
model.save("/content/drive/My Drive/adata/jurkat_probe_only", overwrite=False)

# %%
del(cell_reps)

# %% [markdown]
# load model

# %%
model = MRVI.load("/content/drive/My Drive/adata/jurkat3", adata=adata)

# %%
plt.plot(model.history["elbo_validation"].iloc[5:])
plt.xlabel("Epoch")
plt.ylabel("Validation ELBO")
plt.show()

# %% [markdown]
# # Cell distance

# %%
# Compute local sample representations
cell_reps = model.get_local_sample_representation(
    adata,
    batch_size=512      # helps on large datasets
)
# Out:
# 100%|██████████| 100/100 [00:24<00:00,  4.08it/s]

# %%
np.save("/content/drive/My Drive/adata/jurkat/cell_reps_probe_only.npy", cell_reps)

# %%
del cell_reps

# %%
dists = model.get_local_sample_distances(
    keep_cell=False, groupby="oligo", batch_size=256)
# Out:
# 100%|██████████| 199/199 [01:13<00:00,  2.72it/s]

# %%
type(dists)
# Out:
# xarray.core.dataset.Dataset

# %%
# save dists
dists.to_netcdf("/content/drive/My Drive/adata/jurkat/cell_dists_f_probe_only.png")

# %%
import xarray as xr

dists = xr.load_dataset("/content/drive/My Drive/adata/jurkat/cell_dists_f_probe_only.png")

# %%
dists
# Out:
# <xarray.Dataset> Size: 21kB
# Dimensions:     (sample_x: 17, sample_y: 17, oligo_name: 17)
# Coordinates:
#   * sample_x    (sample_x) object 136B 'ConcanavalinA_1' ... 'PMA_4'
#   * sample_y    (sample_y) object 136B 'ConcanavalinA_1' ... 'PMA_4'
#   * oligo_name  (oligo_name) <U15 1kB 'Media' 'DMSO' ... 'Dynabeads_4'
# Data variables:
#     oligo       (oligo_name, sample_x, sample_y) float32 20kB 0.0 ... 0.0

# %% [markdown]
# Sample distances can be computed using the `get_local_sample_distances` method, which characterizes sample relationships for any cell in the dataset.
# This method can return cell-specific distances (`keep_cell=True`), as well as averaged distances within cell subpopulations, characterized by the `groupby` argument.
# Specifying `keep_cell=False` will ensure that cell-specific distances are not returned, which can reduce the memory footprint of the returned object in the case where many samples are present.
# orig code: dists = model.get_local_sample_distances(
#     keep_cell=False, groupby="initial_clustering", batch_size=32
# )
# d1 = dists.loc[{"initial_clustering_name": "CD16"}].initial_clustering

# %%
drug_dist_df = pd.DataFrame(
        dists['oligo'].mean(axis=0),
        columns = dists['sample_x'].values,
        index = dists['sample_y'].values
)
drug_dist_df
# Out:
#                  ConcanavalinA_1  ConcanavalinA_2  ConcanavalinA_4  \
# ConcanavalinA_1     0.000000e+00         0.000460         0.000352
# ConcanavalinA_2     4.601788e-04         0.000000         0.000109
# ConcanavalinA_4     3.520897e-04         0.000109         0.000000
# DMSO                4.465042e-07         0.000461         0.000353
# Dynabeads_1         2.481685e-04         0.000213         0.000104
# Dynabeads_2         4.154978e-06         0.000464         0.000356
# Dynabeads_4         3.968016e-06         0.000456         0.000348
# Media               4.284312e-06         0.000464         0.000356
# PHA_1               4.035950e-04         0.000057         0.000052
# PHA_2               2.766952e-04         0.000184         0.000076
# PHA_4               3.074115e-04         0.000153         0.000045
# PMA+PHA_1           1.516952e-03         0.001062         0.001170
# PMA+PHA_2           1.515970e-03         0.001061         0.001169
# PMA+PHA_4           1.516966e-03         0.001062         0.001170
# PMA_1               3.504099e-04         0.000110         0.000002
# PMA_2               3.094969e-04         0.000151         0.000043
# PMA_4               4.435683e-04         0.000017         0.000092
#
#                          DMSO  Dynabeads_1   Dynabeads_2  Dynabeads_4  \
# ConcanavalinA_1  4.465042e-07     0.000248  4.154978e-06     0.000004
# ConcanavalinA_2  4.606103e-04     0.000213  4.643023e-04     0.000456
# ConcanavalinA_4  3.525224e-04     0.000104  3.562240e-04     0.000348
# DMSO             0.000000e+00     0.000249  3.719686e-06     0.000004
# Dynabeads_1      2.486026e-04     0.000000  2.523117e-04     0.000244
# Dynabeads_2      3.719686e-06     0.000252  0.000000e+00     0.000008
# Dynabeads_4      4.404251e-06     0.000244  8.120212e-06     0.000000
# Media            3.849220e-06     0.000252  1.441328e-07     0.000008
# PHA_1            4.040274e-04     0.000156  4.077244e-04     0.000400
# PHA_2            2.771290e-04     0.000029  2.808362e-04     0.000273
# PHA_4            3.078448e-04     0.000059  3.115497e-04     0.000303
# PMA+PHA_1        1.517375e-03     0.001273  1.520994e-03     0.001513
# PMA+PHA_2        1.516393e-03     0.001272  1.520012e-03     0.001512
# PMA+PHA_4        1.517388e-03     0.001274  1.521007e-03     0.001513
# PMA_1            3.508427e-04     0.000103  3.545443e-04     0.000346
# PMA_2            3.099302e-04     0.000061  3.136351e-04     0.000306
# PMA_4            4.440000e-04     0.000196  4.476935e-04     0.000440
#
#                         Media     PHA_1     PHA_2     PHA_4     PMA+PHA_1  \
# ConcanavalinA_1  4.284312e-06  0.000404  0.000277  0.000307  1.516952e-03
# ConcanavalinA_2  4.644316e-04  0.000057  0.000184  0.000153  1.062384e-03
# ConcanavalinA_4  3.563534e-04  0.000052  0.000076  0.000045  1.170342e-03
# DMSO             3.849220e-06  0.000404  0.000277  0.000308  1.517375e-03
# Dynabeads_1      2.524412e-04  0.000156  0.000029  0.000059  1.273499e-03
# Dynabeads_2      1.441328e-07  0.000408  0.000281  0.000312  1.520994e-03
# Dynabeads_4      8.249386e-06  0.000400  0.000273  0.000303  1.513096e-03
# Media            0.000000e+00  0.000408  0.000281  0.000312  1.521122e-03
# PHA_1            4.078538e-04  0.000000  0.000127  0.000097  1.118966e-03
# PHA_2            2.809656e-04  0.000127  0.000000  0.000031  1.245263e-03
# PHA_4            3.116791e-04  0.000097  0.000031  0.000000  1.214774e-03
# PMA+PHA_1        1.521122e-03  0.001119  0.001245  0.001215  0.000000e+00
# PMA+PHA_2        1.520140e-03  0.001118  0.001244  0.001214  2.539614e-06
# PMA+PHA_4        1.521136e-03  0.001119  0.001245  0.001215  1.054063e-07
# PMA_1            3.546736e-04  0.000053  0.000074  0.000043  1.172007e-03
# PMA_2            3.137644e-04  0.000094  0.000033  0.000002  1.212709e-03
# PMA_4            4.478228e-04  0.000040  0.000168  0.000137  1.079004e-03
#
#                  PMA+PHA_2     PMA+PHA_4     PMA_1     PMA_2     PMA_4
# ConcanavalinA_1   0.001516  1.516966e-03  0.000350  0.000309  0.000444
# ConcanavalinA_2   0.001061  1.062399e-03  0.000110  0.000151  0.000017
# ConcanavalinA_4   0.001169  1.170357e-03  0.000002  0.000043  0.000092
# DMSO              0.001516  1.517388e-03  0.000351  0.000310  0.000444
# Dynabeads_1       0.001272  1.273514e-03  0.000103  0.000061  0.000196
# Dynabeads_2       0.001520  1.521007e-03  0.000355  0.000314  0.000448
# Dynabeads_4       0.001512  1.513109e-03  0.000346  0.000306  0.000440
# Media             0.001520  1.521136e-03  0.000355  0.000314  0.000448
# PHA_1             0.001118  1.118981e-03  0.000053  0.000094  0.000040
# PHA_2             0.001244  1.245279e-03  0.000074  0.000033  0.000168
# PHA_4             0.001214  1.214789e-03  0.000043  0.000002  0.000137
# PMA+PHA_1         0.000003  1.054063e-07  0.001172  0.001213  0.001079
# PMA+PHA_2         0.000000  2.606087e-06  0.001171  0.001212  0.001078
# PMA+PHA_4         0.000003  0.000000e+00  0.001172  0.001213  0.001079
# PMA_1             0.001171  1.172022e-03  0.000000  0.000041  0.000094
# PMA_2             0.001212  1.212724e-03  0.000041  0.000000  0.000135
# PMA_4             0.001078  1.079020e-03  0.000094  0.000135  0.000000

# %%
# save sample-sample dist matrix
drug_dist_df.to_csv('/content/drive/My Drive/adata/jurkat/dist_df_f_2_probe_only.csv')

# %%
drug_dist_df = pd.read_csv('/content/drive/My Drive/adata/jurkat/dist_df_f_2_probe_only.csv',
    index_col=0)

# %% [markdown]
# The following cell provides useful utility functions to perform hierarchical clustering based on sample distances, as well as to extract sample metadata of interest to visualize the distance matrices

# %%
from scipy.spatial import distance
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import fcluster
from matplotlib.pyplot import gcf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

cluster_method = 'complete'
plt.rcParams['pdf.fonttype'] = 42
dist_matrix = distance.pdist(drug_dist_df)

# Perform hierarchical clustering to get the initial linkage
initial_row_linkage = hierarchy.linkage(dist_matrix, method=cluster_method)

# Apply optimal leaf ordering to get an improved linkage
row_linkage = hierarchy.optimal_leaf_ordering(initial_row_linkage, dist_matrix)
col_linkage = row_linkage # Symmetric clustering

# Get cluster labels based on the optimally ordered linkage
row_col_labels = fcluster(row_linkage, t=.001, criterion='distance')
lut = dict(zip(np.unique(row_col_labels), sns.color_palette("colorblind", n_colors=len(np.unique(row_col_labels)))))
row_col = pd.Series(row_col_labels, index=drug_dist_df.index).map(lut)

sns.set(font_scale=1)


g = sns.clustermap(drug_dist_df,
                   row_linkage=row_linkage,
                   col_linkage=col_linkage,
                   method=cluster_method,
                   row_colors=[row_col],
                   col_colors=[row_col],
                   annot=False,
                   figsize=(35, 35),
                   cmap='magma',
                   yticklabels=True, xticklabels=True,
                   vmin=0, vmax=.001)

# Update legend based on the reordered labels
for label_idx in np.unique(row_col_labels):
    g.ax_col_dendrogram.bar(0, 0, color=lut[label_idx], label=f'Cluster {label_idx}', linewidth=0)

l1 = g.ax_col_dendrogram.legend(
    title='Cluster',
    loc="upper right",
    bbox_to_anchor=(0.18, 0.05),
    bbox_transform=gcf().transFigure,
    ncol=1,
    title_fontsize=80,
    markerscale=10.0
)

g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), rotation=90, fontsize=70)
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(), rotation=360, fontsize=70)
g.ax_cbar.tick_params(labelsize=80)
g.ax_cbar.set_ylabel('Distance', fontsize=80)

for text in l1.get_texts():
    text.set_fontsize(80)

for line in g.ax_row_dendrogram.collections:
    line.set_linewidth(5)
for line in g.ax_col_dendrogram.collections:
    line.set_linewidth(5)


g.savefig('/content/drive/My Drive/adata/jurkat/plots/cluster_heatmap_probe_only.pdf', bbox_inches="tight")
plt.show()
